# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_excel('edutech companies.xlsx')
data
# Out:
#         Company Name  Year of Establishment                    Category  \
# 0            iNeuron                   2018                Data Science
# 1      Coding Blocks                   2014                Data Science
# 2      Coding Ninjas                   2016                Data Science
# 3             Upgrad                   2015                Data Science
# 4         Applied AI                   2017                Data Science
# ..               ...                    ...                         ...
# 115     Career Potli                   2017  Mentorship and Counselling
# 116        InsideIIM                   2011  Mentorship and Counselling
# 117        MYCAPTAIN                   2013  Mentorship and Counselling
# 118  INTERVIEW BUDDY                   2018  Mentorship and Counselling
# 119     IDREAMCAREER                   2013  Mentorship and Counselling
#
#                    Founder  Rating  Turnover (in Cr)
# ...

# %%
data.describe()
# Out:
#        Year of Establishment      Rating  Turnover (in Cr)
# count             120.000000  120.000000        120.000000
# mean             2009.700000    4.370833        553.125000
# std                12.786942    0.473747       2408.161552
# min              1906.000000    3.200000         15.000000
# 25%              2010.000000    4.000000        100.000000
# 50%              2013.000000    4.300000        150.000000
# 75%              2016.000000    4.800000        398.500000
# max              2021.000000    5.000000      25000.000000

# %%
data.isnull().sum()
# Out:
# Company Name             0
# Year of Establishment    0
# Category                 0
# Founder                  0
# Rating                   0
# Turnover (in Cr)         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Company Name           120 non-null    object
#  1   Year of Establishment  120 non-null    int64
#  2   Category               120 non-null    object
#  3   Founder                120 non-null    object
#  4   Rating                 120 non-null    float64
#  5   Turnover (in Cr)       120 non-null    int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.8+ KB

# %%
x = data['Category'].value_counts()

# %% [markdown]
# ## Category based analysis

# %% [markdown]
# ### Category wise distribution of given data

# %%
plt.figure(figsize=(20,10))
colors = sns.color_palette('bright')
lables = ['Data Science','Software Eng','School edu','IIT JEE/NEET','GATE','Kids edu','Mentorship and Counselling']
plt.pie(x,labels = lables, colors = colors, autopct = '%0.0f%%')
plt.show()

# %% [markdown]
# ### which category has over all more revenue generation
# we can say IIT JEE/NEET classes are generating more income according given data

# %%
data.groupby('Category')['Turnover (in Cr)'].sum().sort_index().plot(kind='pie',figsize=(20,10),title = "which category has over all more revenue generation")
# Out:
# <AxesSubplot:title={'center':'which category has over all more revenue generation'}, ylabel='Turnover (in Cr)'>

# %% [markdown]
# ### Rating based on catagories
# ratings start to fall when it comes to school education and software engg

# %%
data.groupby('Category')['Rating'].max().plot(kind='line',figsize=(20,8),title = "Ratings based on categories",marker='D')
# Out:
# <AxesSubplot:title={'center':'Ratings based on categories'}, xlabel='Category'>

# %% [markdown]
# ### No of companies under a category

# %%
x.sort_index().plot(kind='bar',figsize=(20,8),title = "most top ratings",color='green')
# Out:
# <AxesSubplot:title={'center':'most top ratings'}>

# %% [markdown]
# ### in which year most of the given companies where established
# since 2014 we can say the evolution of establishment took place

# %%
data['Year of Establishment'].value_counts().nlargest(10).plot(kind='pie',figsize=(20,10),title = "top years of establishment with most establishment")
# Out:
# <AxesSubplot:title={'center':'top years of establishment with most establishment'}, ylabel='Year of Establishment'>

# %% [markdown]
# ### turn over earned by company according establishment year
# we can say that turn over earned is directly related to establishment year

# %%
data.groupby('Company Name')['Turnover (in Cr)'].sum().sort_values(ascending=False).head(10).plot(kind='pie',figsize=(20,10),title = "most turnovers in cr made by most companies")
# Out:
# <AxesSubplot:title={'center':'most turnovers in cr made by most companies'}, ylabel='Turnover (in Cr)'>

# %% [markdown]
# ### in which year which category is Established more

# %%
data.groupby('Year of Establishment')['Category'].value_counts().nlargest(10).sort_index().plot(kind='pie',figsize=(24,10),title = "most top ratings")
# Out:
# <AxesSubplot:title={'center':'most top ratings'}, ylabel='Category'>

# %% [markdown]
# ### fluctuation in Category according years

# %%
data.groupby('Year of Establishment')['Category'].max().value_counts().sort_index().plot(kind='line',figsize=(20,8),title = "most top ratings",color='orange')
# Out:
# <AxesSubplot:title={'center':'most top ratings'}>

# %%
data.groupby('Year of Establishment')['Category'].value_counts().nlargest(20).sort_index().plot(kind='bar',figsize=(20,8),title = "most top ratings",color='orange')
# Out:
# <AxesSubplot:title={'center':'most top ratings'}, xlabel='Year of Establishment,Category'>

# %% [markdown]
# ### Founder with most companies in same year of establishment

# %%
data.groupby('Year of Establishment')['Founder'].value_counts().sort_index().plot(kind='line',figsize=(20,8),title = "top years of establishment",color='violet')
# Out:
# <AxesSubplot:title={'center':'top years of establishment'}, xlabel='Year of Establishment,Founder'>

# %% [markdown]
# ### a deep look with more insight on same question

# %%
data.groupby('Year of Establishment')['Founder'].value_counts().sort_index().nlargest(20).plot(kind='bar',figsize=(20,8),title = "top years of establishment",color='violet')
# Out:
# <AxesSubplot:title={'center':'top years of establishment'}, xlabel='Year of Establishment,Founder'>

# %%
data.groupby('Year of Establishment')['Founder'].value_counts().sort_index().plot(kind='bar',figsize=(20,8),title = "top years of establishment",color='violet')
# Out:
# <AxesSubplot:title={'center':'top years of establishment'}, xlabel='Year of Establishment,Founder'>

# %%
data['Founder'].value_counts().nlargest(10).plot(kind='pie',figsize=(20,8),title = "top founders with most founded companies")
# Out:
# <AxesSubplot:title={'center':'top founders with most founded companies'}, ylabel='Founder'>

# %%
data['Founder'].value_counts().nlargest(10).plot(kind='line',figsize=(20,8),title = "top years of establishment",marker='D',color='green')
# Out:
# <AxesSubplot:title={'center':'top years of establishment'}>

# %%
data['Turnover (in Cr)'].value_counts().nlargest(10).plot(kind='pie',figsize=(20,8),title = "top turnovers in cr")
# Out:
# <AxesSubplot:title={'center':'top turnovers in cr'}, ylabel='Turnover (in Cr)'>

# %%
data.groupby('Company Name')['Turnover (in Cr)'].max().sort_values(ascending=False).head(10).plot(kind='pie',figsize=(24,8),title = "most turnovers in cr made by most companies")
# Out:
# <AxesSubplot:title={'center':'most turnovers in cr made by most companies'}, ylabel='Turnover (in Cr)'>

# %%
data.groupby('Company Name')['Turnover (in Cr)'].sum().sort_values(ascending=False).plot(kind='bar',figsize=(24,8),title = "most turnovers in cr made by most companies",color='green')
# Out:
# <AxesSubplot:title={'center':'most turnovers in cr made by most companies'}, xlabel='Company Name'>

# %%
data.groupby('Founder')['Turnover (in Cr)'].sum().sort_values(ascending=False).plot(kind='bar',figsize=(24,8),title = "most turnovers in cr made by most companies",color='green')
# Out:
# <AxesSubplot:title={'center':'most turnovers in cr made by most companies'}, xlabel='Founder'>

# %% [markdown]
# ### ratings according to turnover

# %%
data.groupby('Rating')['Turnover (in Cr)'].sum().sort_values(ascending=False).plot(kind='bar',figsize=(24,8),title = "ratings according to turnover",color='yellow')
# Out:
# <AxesSubplot:title={'center':'ratings according to turnover'}, xlabel='Rating'>

# %% [markdown]
# ### Top 10 company Earnd most turnover

# %%
data.groupby('Company Name')['Turnover (in Cr)'].sum().sort_values(ascending=False).nlargest(10).plot(kind='bar',figsize=(24,8),title = "most turnovers in cr made by most companies")
# Out:
# <AxesSubplot:title={'center':'most turnovers in cr made by most companies'}, xlabel='Company Name'>

# %% [markdown]
# ### Most earn-able turnover

# %%
data['Turnover (in Cr)'].value_counts().nlargest(10).plot(kind='bar',figsize=(24,8),title = "most archived turn over by companines",color='orange')
# Out:
# <AxesSubplot:title={'center':'most archived turn over by companines'}>

# %% [markdown]
# ### Most turnover earned founder

# %%
data.groupby('Founder')['Turnover (in Cr)'].sum().nlargest(10).plot(kind='bar',figsize=(24,8),title = "most turnovers in cr made by most companies")
# Out:
# <AxesSubplot:title={'center':'most turnovers in cr made by most companies'}, xlabel='Founder'>

# %%
data.groupby('Category')['Turnover (in Cr)'].value_counts().sort_values(ascending=False).plot(kind='bar',figsize=(24,8),title = "most turnovers in cr made by most companies",color='green')
# Out:
# <AxesSubplot:title={'center':'most turnovers in cr made by most companies'}, xlabel='Category,Turnover (in Cr)'>
